# %%
import requests
import pandas as pd
import json

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=SPCE&apikey=5FAQ9GQ6RC72NKFC'
r = requests.get(url)
data_api = r.json()

# %%
data_api
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'SPCE',
#   '3. Last Refreshed': '2021-08-27',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2021-08-27': {'1. open': '25.5400',
#    '2. high': '26.3800',
#    '3. low': '25.2152',
#    '4. close': '26.0500',
#    '5. volume': '8578308'},
#   '2021-08-26': {'1. open': '26.1000',
#    '2. high': '26.7080',
#    '3. low': '25.2000',
#    '4. close': '25.4500',
#    '5. volume': '10124353'},
#   '2021-08-25': {'1. open': '26.7000',
#    '2. high': '27.0400',
#    '3. low': '25.7519',
#    '4. close': '26.2600',
#    '5. volume': '10425229'},
#   '2021-08-24': {'1. open': '25.5800',
#    '2. high': '26.6500',
#    '3. low': '25.4300',
#    '4. close': '26.4800',
#    '5. volume': '12710058'},
#   '2021-08-23': {'1. open': '24.6000',
#    '2. high': '25.8200',
#    '3. low': '24.5300',
#    '4. close': '25.4400',
# ...

# %%
data = data_api['Time Series (Daily)']

# %%
type(data)
# Out:
# dict

# %%
pd.DataFrame.from_dict(data,orient='index')
# Out:
#             1. open  2. high   3. low 4. close 5. volume
# 2021-08-27  25.5400  26.3800  25.2152  26.0500   8578308
# 2021-08-26  26.1000  26.7080  25.2000  25.4500  10124353
# 2021-08-25  26.7000  27.0400  25.7519  26.2600  10425229
# 2021-08-24  25.5800  26.6500  25.4300  26.4800  12710058
# 2021-08-23  24.6000  25.8200  24.5300  25.4400  10897706
# ...             ...      ...      ...      ...       ...
# 2021-04-14  27.1700  27.5900  26.3900  26.6800   9073635
# 2021-04-13  26.9700  27.5700  26.4700  26.8800  11301600
# 2021-04-12  28.9000  28.9300  26.4600  26.7700  15402374
# 2021-04-09  28.9000  29.4299  28.7920  29.2800   3624954
# 2021-04-08  29.0600  29.4700  28.5000  29.2000   6723578
#
# [100 rows x 5 columns]

# %%
pip install tweepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import tweepy
import tweepy as tw

# your Twitter API key and API secret
my_api_key = "nV5d7KhyJ6obei44dw0QXlZuv"
my_api_secret = "GKoBK5i9AXa0TxJfdKkFUPQioJhItfl3Wq8OiHOQ75n84nxJvo"

# authenticate
auth = tw.OAuthHandler(my_api_key, my_api_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
#search_query = "#virgingalactic -filter:retweets"

# %%
userID = "@virgingalactic"
tweets = api.user_timeline(userID)

# %%
# get tweets from the API
#tweets = tw.Cursor(api.search,              q='\"{}\" -filter:retweets'.format("virgingalactic"),              lang="en",              since="2021-08-01").items(50)



# store the API responses in a list
tweets_copy = []
for tweet in tweets:
    tweets_copy.append(tweet)
    
print("Total Tweets fetched:", len(tweets_copy))
# Out:
# Total Tweets fetched: 20

# %%
tweets_copy
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f95a57daf40>, _json={'created_at': 'Fri Aug 27 21:31:51 +0000 2021', 'id': 1431368891305975812, 'id_str': '1431368891305975812', 'text': 'Experience the lifechanging view of Earth from space.\n\nWe’ve teamed up with @omaze to give you the opportunity to w… https://t.co/fl7vH7w2ZN', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'omaze', 'name': 'Omaze', 'id': 359110231, 'id_str': '359110231', 'indices': [76, 82]}], 'urls': [{'url': 'https://t.co/fl7vH7w2ZN', 'expanded_url': 'https://twitter.com/i/web/status/1431368891305975812', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 26208862, 'id_str': '262088
# ...

# %%
# intialize the dataframe
tweets_df = pd.DataFrame()

# populate the dataframe
for tweet in tweets_copy:
    hashtags = []
    try:
        for hashtag in tweet.entities["hashtags"]:
            hashtags.append(hashtag["text"])
        text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
    except:
        pass
    tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name, 
                                               'user_location': tweet.user.location,\
                                               'user_description': tweet.user.description,
                                               'user_verified': tweet.user.verified,
                                               'date': tweet.created_at,
                                               'text': text, 
                                               'hashtags': [hashtags if hashtags else None],
                                               'source': tweet.source}))
    tweets_df = tweets_df.reset_index(drop=True)

# show the dataframe
tweets_df.head()
# Out:
#          user_name user_location  \
# 0  Virgin Galactic         Earth
# 1  Virgin Galactic         Earth
# 2  Virgin Galactic         Earth
# 3  Virgin Galactic         Earth
# 4  Virgin Galactic         Earth
#
#                                     user_description  user_verified  \
# 0  A new space age is coming. Watch Virgin Galact...           True
# 1  A new space age is coming. Watch Virgin Galact...           True
# 2  A new space age is coming. Watch Virgin Galact...           True
# 3  A new space age is coming. Watch Virgin Galact...           True
# 4  A new space age is coming. Watch Virgin Galact...           True
#
#                  date                                               text  \
# 0 2021-08-27 21:31:51  Experience the lifechanging view of Earth from...
# 1 2021-08-26 18:31:21  Only 67 women have been to space out of 585 as...
# 2 2021-08-25 21:57:09  VMS Eve takes to the skies above Spaceport Ame...
# ...

# %%
df_NumOfTweets = tweets_df

# %%
df_NumOfTweets
# Out:
#           user_name user_location  \
# 0   Virgin Galactic         Earth
# 1   Virgin Galactic         Earth
# 2   Virgin Galactic         Earth
# 3   Virgin Galactic         Earth
# 4   Virgin Galactic         Earth
# 5   Virgin Galactic         Earth
# 6   Virgin Galactic         Earth
# 7   Virgin Galactic         Earth
# 8   Virgin Galactic         Earth
# 9   Virgin Galactic         Earth
# 10  Virgin Galactic         Earth
# 11  Virgin Galactic         Earth
# 12  Virgin Galactic         Earth
# 13  Virgin Galactic         Earth
# 14  Virgin Galactic         Earth
# 15  Virgin Galactic         Earth
# 16  Virgin Galactic         Earth
# 17  Virgin Galactic         Earth
# 18  Virgin Galactic         Earth
# 19  Virgin Galactic         Earth
#
#                                      user_description  user_verified  \
# 0   A new space age is coming. Watch Virgin Galact...           True
# 1   A new space age is coming. Watch Virgin Galact...           True
# ...

# %%
df_NumOfTweets['date'] = df_NumOfTweets['date'].dt.date

# %%
df_NumOfTweets = df_NumOfTweets.groupby(['date']).size()

# %%
df_NumOfTweets
# Out:
# date
# 2021-07-19    1
# 2021-07-20    2
# 2021-07-21    6
# 2021-07-26    1
# 2021-07-27    1
# 2021-07-29    1
# 2021-08-03    1
# 2021-08-05    2
# 2021-08-14    1
# 2021-08-15    1
# 2021-08-25    1
# 2021-08-26    1
# 2021-08-27    1
# dtype: int64
